# %%
"""Raffinons notre quiz
Le quiz que nous avons fait fonctionne très bien mais, il y aurait surement un meilleur moyen de
le faire qu’en utilisant des boucles WHILE.
1) Changez votre quiz pour qu’il inclue des boucles FOR plutôt que des boucles WHILE

Pour aller plus loin : Changeons notre quiz
Notre quiz est vraiment bien, mais on pourrait aussi voir le jeu dans un autre sens et, plutôt que
d’avoir un certain nombre de chance pour finir le quiz, on pourrait plutôt vouloir compter notre
score à la fin du quiz.
1) Changer votre code pour que cela se reflète dans votre programme
a) Vous devrez compter le nombre de bonne réponses
b) Vous devrez compter le nombre de mauvaises réponses
c) A la fin du quiz, vous devrez afficher le nombre de bonnes réponses et le nombre
de mauvaises réponses
d) Si l’utilisateur le souhaite, vous devrez afficher les réponses pour les questions
auxquelles il n’a pas eu juste"""


for i in range (0,3):
    print("il vous reste {} chances".format(3-i))
    question_1 = input("Qui était le dieu suprême de la Grèce antique ?")
    
    if question_1 == "zeus":
        print("bravo vous avez gagné")
        nb_chance = 3-i
        break
    else:
        if i == 2:
            print("ah vous avez perdu le jeu")
            nb_chance = 0
        else:
            print("dommage recommence")
            
            
if nb_chance > 0:
    for i in range(0, nb_chance):
        question_2 = input("Quel fleuve traverse l'Égypte ?")
        if question_2 == "nil":
            print("bravo vous avez repondu juste")
            nb_chance = nb_chance - i
            break
        else:
            if nb_chance == 2:
                print("vous avez perdu")
                
            else:
                print("dommage vous avez mal répondu")
                print("il vous reste {} nombre de chances".format(nb_chance - i - 1))
                
if nb_chance > 0:
    for i in range(0, nb_chance):
        question_3 = input("Quel est le nom de l'agence spatiale ")
        if question_3 == "nasa":
            print("bravo vous avez gagné")
            nb_chance = nb_chance - i
            break
            
        else:
            if i == 2:
                print("vous avez perdu")
            else:
                print("dommage vous avez mal répondu")
                print("il vous reste {} nombre de chances".format(nb_chance - i - 1))
            
if nb_chance > 0:
    print("bravo")
# Out:
# il vous reste 3 chances
# Qui était le dieu suprême de la Grèce antique ?zeus
# bravo vous avez gagné
# Quel fleuve traverse l'Égypte ?nil
# bravo vous avez repondu juste
# Quel est le nom de l'agence spatiale nasa
# bravo vous avez gagné
# bravo

# %%
## exercice 1
"""Construire un quiz

1)	Un bon moyen de pratiquer les conditions est de construire un quiz. Faisons le étape par étape 
a)	Posez une question à l’utilisateur via la console 
b)	Vérifier que la réponse de l’utilisateur soit vraie ou fausse
c)	Si la réponse est vraie, la console devra sortir : “Bravo, c’est la bonne réponse”
d)	Si la réponse est fausse, la console devra sortir :”Dommage, ce n’est pas la bonne réponse”
e)	Posez 3 autres questions sur le même modèle
2)	Nous avons un problème avec notre quiz. Si l’utilisateur n’a pas donné la bonne réponse, le programme passe à la question suivante. On souhaite plutôt que le programme repose la question si l’utilisateur n’a pas donné la bonne réponse 
a)	En utilisant une boucle WHILE, faites en sorte que le programme repose la question à l’utilisateur s’il n’a pas donné la bonne réponse
b)	Réécrivez votre programme pour toutes les autres questions
3)	Maintenant, nous avons un dernier problème. On voudrait que l’utilisateur n’ait que 3 chances pour réussir le quiz 
a)	Améliorer votre programme pour que l’utilisateur n’ait que 3 chances pour réussir le quiz. Si l’utilisateur a répondu faux plus de 3 alors la console devra sortir “Dommage tu as perdu le jeu” et sortir du programme.

Bonus : Faire un mot de passe

1)	Nous voudrions créer un mot de passe avec notre programme
a)	En utilisant une boucle WHILE, modélisez la façon dont on pourrait programme un système très simple d’authentification.
"""

chance = 3

question_1 = input("Qui était le dieu suprême de la Grèce antique ?")

while question_1 != "zeus":
    chance -= 1
    if chance == 0:
        print("t'as perdu")
        break
    else: 
        question_1 = input("Qui était le dieu suprême de la Grèce antique ?")
        
        
if chance > 0:
    question_2 = input("Quel fleuve traverse l'Égypte ?")
    while question_2 != "nil":
        chance -= 1
        if chance == 0:
            print("dommage tu as perdu")
            break
        else:
            question_2 = input("Quel fleuve traverse l'Égypte ?")
            
            
if chance > 0:
    question_3 = input("Quel est le nom de l'agence spatiale ")
    while question_3 != "nasa":
        chance -= 1
        if chance == 0:
            print("dommage tu as perdu")
            break
        else:
            question_3 = input("Quel fleuve traverse l'Égypte ?")
            
            
if chance > 0:
    print("tu as gagné")
# Out:
# Qui était le dieu suprême de la Grèce antique ?zeus
# Quel fleuve traverse l'Égypte ?nil
# Quel est le nom de l'agence spatiale nasa
# tu as gagné
